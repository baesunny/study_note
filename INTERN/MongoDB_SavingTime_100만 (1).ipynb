# %% [markdown]
# ## NOTE

# %% [markdown]
# #### 100만 개 데이터 기준
#
# 1. 몽고디비에서 'plbc.ContainerIoResult', 'plbc.ContainerInOut' 두 컬렉션의 전체 데이터 가져오기
# 2. plbcContainerIoResult는 'copionSeq'기준, plbcContainerInOut는 '_id' 기준으로 join 진행
# 3. join 결과 csv파일로 저장

# %% [markdown]
#     >>> 각 단계별로 시간 얼마나 걸리는지 체크할 것.

# %%
from pymongo import MongoClient
import pymongo
import pandas as pd
import numpy as np
import time
import csv
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from concurrent.futures import ThreadPoolExecutor
import json

# %%
mongodb_URI = "mongodb://splia:splia123!%40%23@211.215.18.231:27018/?authSource=admin&readPreference=primary&appname=MongoDB%20Compass&ssl=false"
client = MongoClient(mongodb_URI)
db = client.plbc

# %%
def get_all_data_in_chunks(collection):
    cursor = collection.find().sort('rgstDem', pymongo.DESCENDING).allow_disk_use(True).limit(1000000)
    while True:
        chunk = list(cursor)
        if not chunk:
            break
        yield chunk

def process_chunk(chunk):
    return [{fieldname: entry.get(fieldname, '') for fieldname in fieldnames} for entry in chunk]

# %% [markdown]
# ---

# %% [markdown]
# # 1. 'plbc.ContainerIoResult', 'plbc.ContainerInOut' 전체 데이터 가져오기

# %% [markdown]
# ## 1-1. plbcContainerIoResult

# %%
collection = db.plbcContainerIoResult

sample_document = collection.find_one()
fieldnames = set(sample_document.keys()) if sample_document else set()

start_time = time.time()
chunks = get_all_data_in_chunks(collection)
data = []
with ThreadPoolExecutor() as executor:
    futures = [executor.submit(process_chunk, chunk) for chunk in chunks]
    for future in futures:
        data.extend(future.result())
end_time = time.time()

loading_time = end_time - start_time
print("plbcContainerIoResult 데이터 로딩하는 데에 걸린 시간:", loading_time, "초")
# Out:
# plbcContainerIoResult 데이터 로딩하는 데에 걸린 시간: 64.57421779632568 초

# %%
# 데이터프레임 변환 시간
start_time = time.time()
plbcContainerIoResult = pd.DataFrame(data)
end_time = time.time()
changing_time = end_time - start_time
print("데이터프레임으로 변환하는 데에 걸린 시간:", changing_time, "초")
# Out:
# 데이터프레임으로 변환하는 데에 걸린 시간: 1.2933681011199951 초

# %%
## 데이터 로딩 + 데이터프레임 변환 시간 합계
IoResult_total = loading_time + changing_time
IoResult_total
# Out:
# 65.86758589744568

# %% [markdown]
# ## 1-2. plbcContainerInOut

# %%
collection = db.plbcContainerInOut

sample_document = collection.find_one()
fieldnames = set(sample_document.keys()) if sample_document else set()

start_time = time.time()
chunks = get_all_data_in_chunks(collection)
data_InOut = []
with ThreadPoolExecutor() as executor:
    futures = [executor.submit(process_chunk, chunk) for chunk in chunks]
    for future in futures:
        data_InOut.extend(future.result())
end_time = time.time()

loading_time = end_time - start_time
print("plbcContainerInOut 데이터 로딩하는 데에 걸린 시간:", loading_time, "초")
# Out:
# plbcContainerInOut 데이터 로딩하는 데에 걸린 시간: 123.83998012542725 초

# %%
# 데이터프레임 변환 시간
start_time = time.time()
plbcContainerInOut = pd.DataFrame(data_InOut)
end_time = time.time()
changing_time = end_time - start_time
print("데이터프레임으로 변환하는 데에 걸린 시간:", changing_time, "초")
# Out:
# 데이터프레임으로 변환하는 데에 걸린 시간: 1.7459089756011963 초

# %%
## 데이터 로딩 + 데이터프레임 변환 시간 합계
InOut_total = loading_time + changing_time
InOut_total
# Out:
# 125.58588910102844

# %% [markdown]
# ---

# %% [markdown]
# # 2. 데이터 JOIN

# %% [markdown]
# #### plbcContainerIoResult는 'copionSeq'기준, plbcContainerInOut는 '_id' 기준으로 join 진행

# %% [markdown]
# #### [데이터정보]
#
# 1. plbc.ContainerIoResult
#       - 전체 데이터 1,000,000개
#       - 칼럼 13개
# ---
# 2. plbc.ContainerInOut
#       - 전체 데이터 1,000,000개
#       - 칼럼 24개

# %%
## 데이터 join

start_time = time.time()
merged_df = pd.merge(plbcContainerIoResult, plbcContainerInOut, left_on='copionSeq', right_on='_id')
end_time = time.time()

joining_time = end_time - start_time
print("데이터 join시간:", joining_time, "초")
# Out:
# 데이터 join시간: 0.8037681579589844 초

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 37 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   ctiorReusltSts2    1000000 non-null  object
#  1   remark_x           1000000 non-null  object
#  2   rgstId_x           1000000 non-null  object
#  3   chgId_x            1000000 non-null  object
#  4   copionSeq          1000000 non-null  object
#  5   ctiorReusltSts3    1000000 non-null  object
#  6   chgDtm             1000000 non-null  datetime64[ns]
#  7   ctiorReusltSts     1000000 non-null  object
#  8   rgstDem_x          1000000 non-null  datetime64[ns]
#  9   ctiorReusltSts5    1000000 non-null  object
#  10  _id_x              1000000 non-null  object
#  11  ctiorReusltSts4    1000000 non-null  object
#  12  ctiorResultDhms    1000000 non-null  object
#  13  ctioIoFlag         1000000 non-null  object
#  14  vechicleId         1000000 non-null  object
#  15  ctioCntrNo2FmFlag  1000000 non-null  object
#  16  rgstDem_y          1000000 non-null  datetime64[ns]
#  17  ctioVehicleRefNo   1000000 non-null  object
#  18  rgstId_y           1000000 non-null  object
#  19  ctioCarrierRefNm   1000000 non-null  object
#  20  ctioBkgDhms        1000000 non-null  object
#  21  ctioTmnlRefnm      1000000 non-null  object
#  22  ctioResponseFlag   1000000 non-null  object
#  23  ctioCntrNo2        1000000 non-null  object
#  24  _id_y              1000000 non-null  object
#  25  ctioReserved2      1000000 non-null  object
#  26  ctioCntr1p1Iso     1000000 non-null  object
#  27  ctioCntrNo1        1000000 non-null  object
#  28  carrierId          1000000 non-null  object
#  29  ctioCntr1p2Iso     1000000 non-null  object
#  30  ctioCntrNo1FmFlag  1000000 non-null  object
#  31  ctioReserved3      1000000 non-null  object
#  32  chgId_y            1000000 non-null  object
#  33  ctioReserved1      1000000 non-null  object
#  34  ctioFaultDesc      1000000 non-null  object
#  35  tmnlId             1000000 non-null  object
#  36  remark_y           1000000 non-null  object
# dtypes: datetime64[ns](3), object(34)
# memory usage: 282.3+ MB

# %% [markdown]
# #### [데이터정보]
#
# 1. merged_df
#     - 데이터 총 1,000,000개
#     - 칼럼 37개

# %% [markdown]
# ---

# %% [markdown]
# # 3. join 결과 csv파일로 저장

# %%
start_time = time.time()
merged_df.to_csv('merged_df.csv', index=False)
end_time = time.time()

saving_time = end_time - start_time
print("CSV파일 저장시간:", saving_time, "초")
# Out:
# CSV파일 저장시간: 6.44290828704834 초

# %%
pd.read_csv('merged_df.csv')
# Out:
# /var/folders/zg/42k25fm91gn9y2_rxlg_vnvc0000gn/T/ipykernel_10688/3888017758.py:1: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv('merged_df.csv')
#         ctiorReusltSts2  remark_x rgstId_x chgId_x  \
# 0                   NaN       NaN   SYSTEM  SYSTEM
# 1                   NaN       NaN   SYSTEM  SYSTEM
# 2                   NaN       NaN   SYSTEM  SYSTEM
# 3                   NaN       NaN   SYSTEM  SYSTEM
# 4                   NaN       NaN   SYSTEM  SYSTEM
# ...                 ...       ...      ...     ...
# 999995              NaN       NaN   SYSTEM  SYSTEM
# 999996              NaN       NaN   SYSTEM  SYSTEM
# 999997              NaN       NaN   SYSTEM  SYSTEM
# 999998              NaN       NaN   SYSTEM  SYSTEM
# 999999              NaN       NaN   SYSTEM  SYSTEM
#
#                                copionSeq  ctiorReusltSts3  \
# 0       bbbef37a562eef7d6104c00e56eafb43              NaN
# 1       bbb25a24cf25fc9e090c683532bc7176              NaN
# 2       de7de91a1187b4363d16fd9957ac8f9f              NaN
# 3       4c660f46d77c02779365cb2b65e935a6              NaN
# 4       d8db7a4b2521842f438f4e4aa0dddcb0              NaN
# ...                                  ...              ...
# 999995  1a54f1e683365dc8d93e7e2c1801a3bc              NaN
# 999996  bce6383a7c311234136d82ae372dc66d              NaN
# 999997  bf02c9f7b76c4d6804fdcd5b6031be59              NaN
# 999998  d28605d392dcc1b7cd0a83b9096fbec9              NaN
# 999999  acf6d8a607baf5055733bf0de9243cd1              NaN
#
#                          chgDtm ctiorReusltSts                rgstDem_x  \
# 0       2024-02-06 15:00:17.101             OK  2024-02-06 15:00:17.101
# 1       2024-02-06 15:00:17.101             OK  2024-02-06 15:00:17.101
# 2       2024-02-06 15:00:17.101             OK  2024-02-06 15:00:17.101
# 3       2024-02-06 15:00:17.101             OK  2024-02-06 15:00:17.101
# 4       2024-02-06 15:00:17.101             OK  2024-02-06 15:00:17.101
# ...                         ...            ...                      ...
# 999995  2023-11-05 15:00:15.455             OK  2023-11-05 15:00:15.455
# 999996  2023-11-05 15:00:15.455             OK  2023-11-05 15:00:15.455
# 999997  2023-11-05 15:00:15.455             OK  2023-11-05 15:00:15.455
# 999998  2023-11-05 15:00:15.455             OK  2023-11-05 15:00:15.455
# 999999  2023-11-05 15:00:15.455             OK  2023-11-05 15:00:15.455
#
#         ctiorReusltSts5  ...  ctioCntrNo1  carrierId ctioCntr1p2Iso  \
# 0                   NaN  ...  GAOU6602217        NaN            NaN
# 1                   NaN  ...          NaN        NaN            NaN
# 2                   NaN  ...          NaN        NaN            NaN
# 3                   NaN  ...  BMOU9804188        NaN            NaN
# 4                   NaN  ...          NaN        NaN            NaN
# ...                 ...  ...          ...        ...            ...
# 999995              NaN  ...  TGBU4627859        NaN            NaN
# 999996              NaN  ...  MSMU6423243        NaN            NaN
# 999997              NaN  ...  MRKU6031050        NaN            NaN
# 999998              NaN  ...  TCNU3597723        NaN            NaN
# 999999              NaN  ...  SEGU4690270        NaN            NaN
#
#        ctioCntrNo1FmFlag  ctioReserved3  chgId_y ctioReserved1 ctioFaultDesc  \
# 0                    5.0            NaN   SYSTEM           NaN           NaN
# 1                    4.0            NaN   SYSTEM           NaN           NaN
# 2                    4.0            NaN   SYSTEM           NaN           NaN
# 3                    5.0            NaN   SYSTEM           NaN           NaN
# 4                    4.0            NaN   SYSTEM           NaN           NaN
# ...                  ...            ...      ...           ...           ...
# 999995               5.0            NaN   SYSTEM           NaN           NaN
# 999996               5.0            NaN   SYSTEM           NaN           NaN
# 999997               5.0            NaN   SYSTEM           NaN           NaN
# 999998               5.0            NaN   SYSTEM           NaN           NaN
# 999999               5.0            NaN   SYSTEM           NaN           NaN
#
#           tmnlId remark_y
# 0       HPNTC010      NaN
# 1       HPNTC010      NaN
# 2       HPNTC010      NaN
# 3       HPNTC010      NaN
# 4       HPNTC010      NaN
# ...          ...      ...
# 999995  PNCOC010      NaN
# 999996  PNCOC010      NaN
# 999997  PNCOC010      NaN
# 999998  PNCOC010      NaN
# 999999  PNCOC010      NaN
#
# [1000000 rows x 37 columns]

# %% [markdown]
# ---

# %% [markdown]
# # 04. join 결과 JSON 파일 저장

# %%
start_time = time.time()
merged_df.to_json('merged_df.json', orient='records')
end_time = time.time()

saving_time_json = end_time - start_time

print("JSON파일 저장 시간:", saving_time, "초")
# Out:
# JSON파일 저장 시간: 6.44290828704834 초

# %%
pd.read_json('merged_df.json')
# Out:
#        ctiorReusltSts2 remark_x rgstId_x chgId_x  \
# 0                                 SYSTEM  SYSTEM
# 1                                 SYSTEM  SYSTEM
# 2                                 SYSTEM  SYSTEM
# 3                                 SYSTEM  SYSTEM
# 4                                 SYSTEM  SYSTEM
# ...                ...      ...      ...     ...
# 999995                            SYSTEM  SYSTEM
# 999996                            SYSTEM  SYSTEM
# 999997                            SYSTEM  SYSTEM
# 999998                            SYSTEM  SYSTEM
# 999999                            SYSTEM  SYSTEM
#
#                                copionSeq ctiorReusltSts3         chgDtm  \
# 0       bbbef37a562eef7d6104c00e56eafb43                  1707231617101
# 1       bbb25a24cf25fc9e090c683532bc7176                  1707231617101
# 2       de7de91a1187b4363d16fd9957ac8f9f                  1707231617101
# 3       4c660f46d77c02779365cb2b65e935a6                  1707231617101
# 4       d8db7a4b2521842f438f4e4aa0dddcb0                  1707231617101
# ...                                  ...             ...            ...
# 999995  1a54f1e683365dc8d93e7e2c1801a3bc                  1699196415455
# 999996  bce6383a7c311234136d82ae372dc66d                  1699196415455
# 999997  bf02c9f7b76c4d6804fdcd5b6031be59                  1699196415455
# 999998  d28605d392dcc1b7cd0a83b9096fbec9                  1699196415455
# 999999  acf6d8a607baf5055733bf0de9243cd1                  1699196415455
#
#        ctiorReusltSts      rgstDem_x ctiorReusltSts5  ...  ctioCntrNo1  \
# 0                  OK  1707231617101                  ...  GAOU6602217
# 1                  OK  1707231617101                  ...
# 2                  OK  1707231617101                  ...
# 3                  OK  1707231617101                  ...  BMOU9804188
# 4                  OK  1707231617101                  ...
# ...               ...            ...             ...  ...          ...
# 999995             OK  1699196415455                  ...  TGBU4627859
# 999996             OK  1699196415455                  ...  MSMU6423243
# 999997             OK  1699196415455                  ...  MRKU6031050
# 999998             OK  1699196415455                  ...  TCNU3597723
# 999999             OK  1699196415455                  ...  SEGU4690270
#
#        carrierId ctioCntr1p2Iso ctioCntrNo1FmFlag ctioReserved3 chgId_y  \
# 0                                               5                SYSTEM
# 1                                               4                SYSTEM
# 2                                               4                SYSTEM
# 3                                               5                SYSTEM
# 4                                               4                SYSTEM
# ...          ...            ...               ...           ...     ...
# 999995                                          5                SYSTEM
# 999996                                          5                SYSTEM
# 999997                                          5                SYSTEM
# 999998                                          5                SYSTEM
# 999999                                          5                SYSTEM
#
#         ctioReserved1 ctioFaultDesc    tmnlId remark_y
# 0                                    HPNTC010
# 1                                    HPNTC010
# 2                                    HPNTC010
# 3                                    HPNTC010
# 4                                    HPNTC010
# ...               ...           ...       ...      ...
# 999995                               PNCOC010
# 999996                               PNCOC010
# 999997                               PNCOC010
# 999998                               PNCOC010
# 999999                               PNCOC010
#
# [1000000 rows x 37 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## 04. 전체시간

# %%
IoResult_total + InOut_total + joining_time + saving_time
# Out:
# 198.70015144348145

# %%
198.70015144348145/60
# Out:
# 3.311669190724691

# %% [markdown]
# - MongoDB에서 Join 후에 가져오는 방식 >> 298초 소요됨.
